# %%
import requests
from bs4 import  BeautifulSoup
from os.path import exists
import MongoDbSupport

# %%
def arxiv_pages(code):
    

    header={'User-Agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36"}
    url=f"https://arxiv.org/search/?query={code}&searchtype=all&abstracts=hide&order=-announced_date_first&size=50"

    url="https://arxiv.org/list/cs/pastweek?show=1558"
    
    #print(url)
    res=requests.get(url,headers=header)
    
    soup=BeautifulSoup(res.text,"html.parser")
    pdfs=soup.find_all("span",class_="list-identifier")
    pdflist=[]
    for pdf in pdfs:
        st=pdf.a["href"]
        st=st.replace("abs","pdf")
        st="https://arxiv.org"+st+".pdf"
        pdflist.append(st)
    #pages_txt=pages[0].text.strip()
    #print(pages_txt)
 
    return(pdflist)

# %%
pdflist=arxiv_pages("NLP")

# %%
pdflist
# Out:
# ['https://arxiv.org/pdf/2203.17276.pdf',
#  'https://arxiv.org/pdf/2203.17275.pdf',
#  'https://arxiv.org/pdf/2203.17274.pdf',
#  'https://arxiv.org/pdf/2203.17273.pdf',
#  'https://arxiv.org/pdf/2203.17272.pdf',
#  'https://arxiv.org/pdf/2203.17271.pdf',
#  'https://arxiv.org/pdf/2203.17270.pdf',
#  'https://arxiv.org/pdf/2203.17269.pdf',
#  'https://arxiv.org/pdf/2203.17266.pdf',
#  'https://arxiv.org/pdf/2203.17265.pdf',
#  'https://arxiv.org/pdf/2203.17263.pdf',
#  'https://arxiv.org/pdf/2203.17261.pdf',
#  'https://arxiv.org/pdf/2203.17260.pdf',
#  'https://arxiv.org/pdf/2203.17259.pdf',
#  'https://arxiv.org/pdf/2203.17257.pdf',
#  'https://arxiv.org/pdf/2203.17256.pdf',
#  'https://arxiv.org/pdf/2203.17253.pdf',
#  'https://arxiv.org/pdf/2203.17251.pdf',
#  'https://arxiv.org/pdf/2203.17250.pdf',
#  'https://arxiv.org/pdf/2203.17248.pdf',
#  'https://arxiv.org/pdf/2203.17247.pdf',
#  'https://arxiv.org/pdf/2203.17242.pdf',
#  'https://arxiv.org/pdf/2203.17240.pdf',
#  'https://arxiv.org/pdf/2203.17239.pdf',
#  'https://arxiv.org/pdf/2203.17234.pdf',
#  'https://arxiv.org/pdf/2203.17232.pdf',
#  'https://arxiv.org/pdf/2203.17225.pdf',
#  'https://arxiv.org/pdf/2203.17219.pdf',
#  'https://arxiv.org/pdf/2203.17217.pdf',
#  'https://arxiv.org/pdf/2203.17213.pdf',
#  'https://arxiv.org/pdf/2203.17211.pdf',
#  'https://arxiv.org/pdf/2203.17209.pdf',
#  'https://arxiv.org/pdf/2203.17205.pdf',
#  'https://arxiv.org/pdf/2203.17200.pdf',
#  'https://arxiv.org/pdf/2203.17196.pdf',
#  'https://arxiv.org/pdf/2203.17194.pdf',
#  'https://arxiv.org/pdf/2203.17193.pdf',
#  'https://arxiv.org/pdf/2203.17191.pdf',
#  'https://arxiv.org/pdf/2203.17189.pdf',
#  'https://arxiv.org/pdf/2203.17184.pdf',
#  'https://arxiv.org/pdf/2203.17182.pdf',
#  'https://arxiv.org/pdf/2203.17179.pdf',
#  'https://arxiv.org/pdf/2203.17178.pdf',
#  'https://arxiv.org/pdf/2203.17174.pdf',
#  'https://arxiv.org/pdf/2203.17168.pdf',
#  'https://arxiv.org/pdf/2203.17167.pdf',
#  'https://arxiv.org/pdf/2203.17166.pdf',
#  'https://arxiv.org/pdf/2203.17165.pdf',
#  'https://arxiv.org/pdf/2203.17159.pdf',
#  'https://arxiv.org/pdf/2203.17156.pdf',
#  'https://arxiv.org/pdf/2203.17155.pdf',
#  'https://arxiv.org/pdf/2203.17152.pdf',
#  'https://arxiv.org/pdf/2203.17150.pdf',
#  'https://arxiv.org/pdf/2203.17149.pdf',
#  'https://arxiv.org/pdf/2203.17146.pdf',
#  'https://arxiv.org/pdf/2203.17144.pdf',
#  'https://arxiv.org/pdf/2203.17139.pdf',
#  'https://arxiv.org/pdf/2203.17138.pdf',
#  'https://arxiv.org/pdf/2203.17134.pdf',
#  'https://arxiv.org/pdf/2203.17132.pdf',
#  'https://arxiv.org/pdf/2203.17128.pdf',
#  'https://arxiv.org/pdf/2203.17125.pdf',
#  'https://arxiv.org/pdf/2203.17118.pdf',
#  'https://arxiv.org/pdf/2203.17117.pdf',
#  'https://arxiv.org/pdf/2203.17114.pdf',
#  'https://arxiv.org/pdf/2203.17113.pdf',
#  'https://arxiv.org/pdf/2203.17112.pdf',
#  'https://arxiv.org/pdf/2203.17110.pdf',
#  'https://arxiv.org/pdf/2203.17109.pdf',
#  'https://arxiv.org/pdf/2203.17106.pdf',
#  'https://arxiv.org/pdf/2203.17105.pdf',
#  'https://arxiv.org/pdf/2203.17103.pdf',
#  'https://arxiv.org/pdf/2203.17102.pdf',
#  'https://arxiv.org/pdf/2203.17096.pdf',
#  'https://arxiv.org/pdf/2203.17090.pdf',
#  'https://arxiv.org/pdf/2203.17085.pdf',
#  'https://arxiv.org/pdf/2203.17081.pdf',
#  'https://arxiv.org/pdf/2203.17079.pdf',
#  'https://arxiv.org/pdf/2203.17076.pdf',
#  'https://arxiv.org/pdf/2203.17072.pdf',
#  'https://arxiv.org/pdf/2203.17070.pdf',
#  'https://arxiv.org/pdf/2203.17067.pdf',
#  'https://arxiv.org/pdf/2203.17063.pdf',
#  'https://arxiv.org/pdf/2203.17055.pdf',
#  'https://arxiv.org/pdf/2203.17054.pdf',
#  'https://arxiv.org/pdf/2203.17052.pdf',
#  'https://arxiv.org/pdf/2203.17051.pdf',
#  'https://arxiv.org/pdf/2203.17045.pdf',
#  'https://arxiv.org/pdf/2203.17044.pdf',
#  'https://arxiv.org/pdf/2203.17042.pdf',
#  'https://arxiv.org/pdf/2203.17041.pdf',
#  'https://arxiv.org/pdf/2203.17031.pdf',
#  'https://arxiv.org/pdf/2203.17030.pdf',
#  'https://arxiv.org/pdf/2203.17027.pdf',
#  'https://arxiv.org/pdf/2203.17024.pdf',
#  'https://arxiv.org/pdf/2203.17023.pdf',
#  'https://arxiv.org/pdf/2203.17020.pdf',
#  'https://arxiv.org/pdf/2203.17018.pdf',
#  'https://arxiv.org/pdf/2203.17013.pdf',
#  'https://arxiv.org/pdf/2203.17012.pdf',
#  'https://arxiv.org/pdf/2203.17010.pdf',
#  'https://arxiv.org/pdf/2203.17008.pdf',
#  'https://arxiv.org/pdf/2203.17007.pdf',
#  'https://arxiv.org/pdf/2203.17005.pdf',
#  'https://arxiv.org/pdf/2203.17003.pdf',
#  'https://arxiv.org/pdf/2203.17002.pdf',
#  'https://arxiv.org/pdf/2203.16997.pdf',
#  'https://arxiv.org/pdf/2203.16995.pdf',
#  'https://arxiv.org/pdf/2203.16992.pdf',
#  'https://arxiv.org/pdf/2203.16989.pdf',
#  'https://arxiv.org/pdf/2203.16988.pdf',
#  'https://arxiv.org/pdf/2203.16987.pdf',
#  'https://arxiv.org/pdf/2203.16983.pdf',
#  'https://arxiv.org/pdf/2203.16981.pdf',
#  'https://arxiv.org/pdf/2203.16978.pdf',
#  'https://arxiv.org/pdf/2203.16973.pdf',
#  'https://arxiv.org/pdf/2203.16970.pdf',
#  'https://arxiv.org/pdf/2203.16969.pdf',
#  'https://arxiv.org/pdf/2203.16966.pdf',
#  'https://arxiv.org/pdf/2203.16965.pdf',
#  'https://arxiv.org/pdf/2203.16964.pdf',
#  'https://arxiv.org/pdf/2203.16962.pdf',
#  'https://arxiv.org/pdf/2203.16960.pdf',
#  'https://arxiv.org/pdf/2203.16954.pdf',
#  'https://arxiv.org/pdf/2203.16952.pdf',
#  'https://arxiv.org/pdf/2203.16945.pdf',
#  'https://arxiv.org/pdf/2203.16942.pdf',
#  'https://arxiv.org/pdf/2203.16941.pdf',
#  'https://arxiv.org/pdf/2203.16939.pdf',
#  'https://arxiv.org/pdf/2203.16937.pdf',
#  'https://arxiv.org/pdf/2203.16935.pdf',
#  'https://arxiv.org/pdf/2203.16934.pdf',
#  'https://arxiv.org/pdf/2203.16932.pdf',
#  'https://arxiv.org/pdf/2203.16931.pdf',
#  'https://arxiv.org/pdf/2203.16930.pdf',
#  'https://arxiv.org/pdf/2203.16928.pdf',
#  'https://arxiv.org/pdf/2203.16927.pdf',
#  'https://arxiv.org/pdf/2203.16926.pdf',
#  'https://arxiv.org/pdf/2203.16924.pdf',
#  'https://arxiv.org/pdf/2203.16923.pdf',
#  'https://arxiv.org/pdf/2203.16922.pdf',
#  'https://arxiv.org/pdf/2203.16921.pdf',
#  'https://arxiv.org/pdf/2203.16920.pdf',
#  'https://arxiv.org/pdf/2203.16915.pdf',
#  'https://arxiv.org/pdf/2203.16912.pdf',
#  'https://arxiv.org/pdf/2203.16910.pdf',
#  'https://arxiv.org/pdf/2203.16908.pdf',
#  'https://arxiv.org/pdf/2203.16898.pdf',
#  'https://arxiv.org/pdf/2203.16897.pdf',
#  'https://arxiv.org/pdf/2203.16896.pdf',
#  'https://arxiv.org/pdf/2203.16895.pdf',
#  'https://arxiv.org/pdf/2203.16894.pdf',
#  'https://arxiv.org/pdf/2203.16891.pdf',
#  'https://arxiv.org/pdf/2203.16890.pdf',
#  'https://arxiv.org/pdf/2203.16887.pdf',
#  'https://arxiv.org/pdf/2203.16885.pdf',
#  'https://arxiv.org/pdf/2203.16882.pdf',
#  'https://arxiv.org/pdf/2203.16875.pdf',
#  'https://arxiv.org/pdf/2203.16874.pdf',
#  'https://arxiv.org/pdf/2203.16872.pdf',
#  'https://arxiv.org/pdf/2203.16871.pdf',
#  'https://arxiv.org/pdf/2203.16870.pdf',
#  'https://arxiv.org/pdf/2203.16869.pdf',
#  'https://arxiv.org/pdf/2203.16867.pdf',
#  'https://arxiv.org/pdf/2203.16864.pdf',
#  'https://arxiv.org/pdf/2203.16863.pdf',
#  'https://arxiv.org/pdf/2203.16860.pdf',
#  'https://arxiv.org/pdf/2203.16859.pdf',
#  'https://arxiv.org/pdf/2203.16857.pdf',
#  'https://arxiv.org/pdf/2203.16854.pdf',
#  'https://arxiv.org/pdf/2203.16851.pdf',
#  'https://arxiv.org/pdf/2203.16845.pdf',
#  'https://arxiv.org/pdf/2203.16844.pdf',
#  'https://arxiv.org/pdf/2203.16838.pdf',
#  'https://arxiv.org/pdf/2203.16834.pdf',
#  'https://arxiv.org/pdf/2203.16832.pdf',
#  'https://arxiv.org/pdf/2203.16828.pdf',
#  'https://arxiv.org/pdf/2203.16826.pdf',
#  'https://arxiv.org/pdf/2203.16825.pdf',
#  'https://arxiv.org/pdf/2203.16823.pdf',
#  'https://arxiv.org/pdf/2203.16816.pdf',
#  'https://arxiv.org/pdf/2203.16811.pdf',
#  'https://arxiv.org/pdf/2203.16810.pdf',
#  'https://arxiv.org/pdf/2203.16807.pdf',
#  'https://arxiv.org/pdf/2203.16804.pdf',
#  'https://arxiv.org/pdf/2203.16803.pdf',
#  'https://arxiv.org/pdf/2203.16802.pdf',
#  'https://arxiv.org/pdf/2203.16801.pdf',
#  'https://arxiv.org/pdf/2203.16800.pdf',
#  'https://arxiv.org/pdf/2203.16799.pdf',
#  'https://arxiv.org/pdf/2203.16798.pdf',
#  'https://arxiv.org/pdf/2203.16797.pdf',
#  'https://arxiv.org/pdf/2203.16796.pdf',
#  'https://arxiv.org/pdf/2203.16795.pdf',
#  'https://arxiv.org/pdf/2203.16794.pdf',
#  'https://arxiv.org/pdf/2203.16793.pdf',
#  'https://arxiv.org/pdf/2203.16792.pdf',
#  'https://arxiv.org/pdf/2203.16788.pdf',
#  'https://arxiv.org/pdf/2203.16787.pdf',
#  'https://arxiv.org/pdf/2203.16786.pdf',
#  'https://arxiv.org/pdf/2203.16784.pdf',
#  'https://arxiv.org/pdf/2203.16782.pdf',
#  'https://arxiv.org/pdf/2203.16781.pdf',
#  'https://arxiv.org/pdf/2203.16780.pdf',
#  'https://arxiv.org/pdf/2203.16778.pdf',
#  'https://arxiv.org/pdf/2203.16777.pdf',
#  'https://arxiv.org/pdf/2203.16775.pdf',
#  'https://arxiv.org/pdf/2203.16772.pdf',
#  'https://arxiv.org/pdf/2203.16771.pdf',
#  'https://arxiv.org/pdf/2203.16768.pdf',
#  'https://arxiv.org/pdf/2203.16767.pdf',
#  'https://arxiv.org/pdf/2203.16765.pdf',
#  'https://arxiv.org/pdf/2203.16763.pdf',
#  'https://arxiv.org/pdf/2203.16762.pdf',
#  'https://arxiv.org/pdf/2203.16761.pdf',
#  'https://arxiv.org/pdf/2203.16760.pdf',
#  'https://arxiv.org/pdf/2203.16756.pdf',
#  'https://arxiv.org/pdf/2203.16755.pdf',
#  'https://arxiv.org/pdf/2203.16754.pdf',
#  'https://arxiv.org/pdf/2203.16751.pdf',
#  'https://arxiv.org/pdf/2203.16748.pdf',
#  'https://arxiv.org/pdf/2203.16747.pdf',
#  'https://arxiv.org/pdf/2203.16746.pdf',
#  'https://arxiv.org/pdf/2203.16745.pdf',
#  'https://arxiv.org/pdf/2203.16743.pdf',
#  'https://arxiv.org/pdf/2203.16738.pdf',
#  'https://arxiv.org/pdf/2203.16732.pdf',
#  'https://arxiv.org/pdf/2203.16730.pdf',
#  'https://arxiv.org/pdf/2203.16723.pdf',
#  'https://arxiv.org/pdf/2203.16718.pdf',
#  'https://arxiv.org/pdf/2203.16715.pdf',
#  'https://arxiv.org/pdf/2203.16714.pdf',
#  'https://arxiv.org/pdf/2203.16713.pdf',
#  'https://arxiv.org/pdf/2203.16708.pdf',
#  'https://arxiv.org/pdf/2203.16701.pdf',
#  'https://arxiv.org/pdf/2203.16699.pdf',
#  'https://arxiv.org/pdf/2203.16697.pdf',
#  'https://arxiv.org/pdf/2203.16690.pdf',
#  'https://arxiv.org/pdf/2203.16687.pdf',
#  'https://arxiv.org/pdf/2203.16684.pdf',
#  'https://arxiv.org/pdf/2203.16682.pdf',
#  'https://arxiv.org/pdf/2203.16681.pdf',
#  'https://arxiv.org/pdf/2203.16680.pdf',
#  'https://arxiv.org/pdf/2203.16678.pdf',
#  'https://arxiv.org/pdf/2203.16670.pdf',
#  'https://arxiv.org/pdf/2203.16669.pdf',
#  'https://arxiv.org/pdf/2203.16668.pdf',
#  'https://arxiv.org/pdf/2203.16666.pdf',
#  'https://arxiv.org/pdf/2203.16664.pdf',
#  'https://arxiv.org/pdf/2203.16663.pdf',
#  'https://arxiv.org/pdf/2203.16660.pdf',
#  'https://arxiv.org/pdf/2203.16657.pdf',
#  'https://arxiv.org/pdf/2203.16654.pdf',
#  'https://arxiv.org/pdf/2203.16653.pdf',
#  'https://arxiv.org/pdf/2203.16650.pdf',
#  'https://arxiv.org/pdf/2203.16648.pdf',
#  'https://arxiv.org/pdf/2203.16646.pdf',
#  'https://arxiv.org/pdf/2203.16643.pdf',
#  'https://arxiv.org/pdf/2203.16640.pdf',
#  'https://arxiv.org/pdf/2203.16639.pdf',
#  'https://arxiv.org/pdf/2203.16637.pdf',
#  'https://arxiv.org/pdf/2203.16634.pdf',
#  'https://arxiv.org/pdf/2203.16633.pdf',
#  'https://arxiv.org/pdf/2203.16632.pdf',
#  'https://arxiv.org/pdf/2203.16628.pdf',
#  'https://arxiv.org/pdf/2203.16626.pdf',
#  'https://arxiv.org/pdf/2203.16621.pdf',
#  'https://arxiv.org/pdf/2203.16620.pdf',
#  'https://arxiv.org/pdf/2203.16618.pdf',
#  'https://arxiv.org/pdf/2203.16616.pdf',
#  'https://arxiv.org/pdf/2203.16615.pdf',
#  'https://arxiv.org/pdf/2203.16612.pdf',
#  'https://arxiv.org/pdf/2203.16604.pdf',
#  'https://arxiv.org/pdf/2203.16603.pdf',
#  'https://arxiv.org/pdf/2203.16601.pdf',
#  'https://arxiv.org/pdf/2203.16600.pdf',
#  'https://arxiv.org/pdf/2203.16599.pdf',
#  'https://arxiv.org/pdf/2203.16597.pdf',
#  'https://arxiv.org/pdf/2203.16595.pdf',
#  'https://arxiv.org/pdf/2203.16588.pdf',
#  'https://arxiv.org/pdf/2203.16586.pdf',
#  'https://arxiv.org/pdf/2203.16582.pdf',
#  'https://arxiv.org/pdf/2203.16578.pdf',
#  'https://arxiv.org/pdf/2203.16577.pdf',
#  'https://arxiv.org/pdf/2203.16574.pdf',
#  'https://arxiv.org/pdf/2203.16573.pdf',
#  'https://arxiv.org/pdf/2203.16569.pdf',
#  'https://arxiv.org/pdf/2203.16542.pdf',
#  'https://arxiv.org/pdf/2203.16540.pdf',
#  'https://arxiv.org/pdf/2203.16539.pdf',
#  'https://arxiv.org/pdf/2203.16538.pdf',
#  'https://arxiv.org/pdf/2203.16537.pdf',
#  'https://arxiv.org/pdf/2203.16536.pdf',
#  'https://arxiv.org/pdf/2203.16535.pdf',
#  'https://arxiv.org/pdf/2203.17255.pdf',
#  'https://arxiv.org/pdf/2203.17241.pdf',
#  'https://arxiv.org/pdf/2203.17226.pdf',
#  'https://arxiv.org/pdf/2203.17218.pdf',
#  'https://arxiv.org/pdf/2203.17215.pdf',
#  'https://arxiv.org/pdf/2203.17207.pdf',
#  'https://arxiv.org/pdf/2203.17190.pdf',
#  'https://arxiv.org/pdf/2203.17164.pdf',
#  'https://arxiv.org/pdf/2203.17153.pdf',
#  'https://arxiv.org/pdf/2203.17145.pdf',
#  'https://arxiv.org/pdf/2203.17143.pdf',
#  'https://arxiv.org/pdf/2203.17089.pdf',
#  'https://arxiv.org/pdf/2203.17068.pdf',
#  'https://arxiv.org/pdf/2203.17066.pdf',
#  'https://arxiv.org/pdf/2203.17065.pdf',
#  'https://arxiv.org/pdf/2203.17056.pdf',
#  'https://arxiv.org/pdf/2203.17040.pdf',
#  'https://arxiv.org/pdf/2203.17036.pdf',
#  'https://arxiv.org/pdf/2203.17028.pdf',
#  'https://arxiv.org/pdf/2203.17019.pdf',
#  'https://arxiv.org/pdf/2203.17006.pdf',
#  'https://arxiv.org/pdf/2203.17004.pdf',
#  'https://arxiv.org/pdf/2203.17001.pdf',
#  'https://arxiv.org/pdf/2203.16996.pdf',
#  'https://arxiv.org/pdf/2203.16944.pdf',
#  'https://arxiv.org/pdf/2203.16940.pdf',
#  'https://arxiv.org/pdf/2203.16900.pdf',
#  'https://arxiv.org/pdf/2203.16868.pdf',
#  'https://arxiv.org/pdf/2203.16865.pdf',
#  'https://arxiv.org/pdf/2203.16861.pdf',
#  'https://arxiv.org/pdf/2203.16852.pdf',
#  'https://arxiv.org/pdf/2203.16843.pdf',
#  'https://arxiv.org/pdf/2203.16840.pdf',
#  'https://arxiv.org/pdf/2203.16822.pdf',
#  'https://arxiv.org/pdf/2203.16805.pdf',
#  'https://arxiv.org/pdf/2203.16776.pdf',
#  'https://arxiv.org/pdf/2203.16773.pdf',
#  'https://arxiv.org/pdf/2203.16758.pdf',
#  'https://arxiv.org/pdf/2203.16757.pdf',
#  'https://arxiv.org/pdf/2203.16749.pdf',
#  'https://arxiv.org/pdf/2203.16711.pdf',
#  'https://arxiv.org/pdf/2203.16707.pdf',
#  'https://arxiv.org/pdf/2203.16706.pdf',
#  'https://arxiv.org/pdf/2203.16705.pdf',
#  'https://arxiv.org/pdf/2203.16691.pdf',
#  'https://arxiv.org/pdf/2203.16685.pdf',
#  'https://arxiv.org/pdf/2203.16683.pdf',
#  'https://arxiv.org/pdf/2203.16673.pdf',
#  'https://arxiv.org/pdf/2203.16662.pdf',
#  'https://arxiv.org/pdf/2203.16642.pdf',
#  'https://arxiv.org/pdf/2203.16622.pdf',
#  'https://arxiv.org/pdf/2203.16614.pdf',
#  'https://arxiv.org/pdf/2203.16606.pdf',
#  'https://arxiv.org/pdf/2203.16587.pdf',
#  'https://arxiv.org/pdf/2203.16557.pdf',
#  'https://arxiv.org/pdf/2203.15937.pdf',
#  'https://arxiv.org/pdf/2109.03379.pdf',
#  'https://arxiv.org/pdf/2203.16533.pdf',
#  'https://arxiv.org/pdf/2203.16531.pdf',
#  'https://arxiv.org/pdf/2203.16530.pdf',
#  'https://arxiv.org/pdf/2203.16529.pdf',
#  'https://arxiv.org/pdf/2203.16528.pdf',
#  'https://arxiv.org/pdf/2203.16527.pdf',
#  'https://arxiv.org/pdf/2203.16521.pdf',
#  'https://arxiv.org/pdf/2203.16518.pdf',
#  'https://arxiv.org/pdf/2203.16517.pdf',
#  'https://arxiv.org/pdf/2203.16516.pdf',
#  'https://arxiv.org/pdf/2203.16515.pdf',
#  'https://arxiv.org/pdf/2203.16513.pdf',
#  'https://arxiv.org/pdf/2203.16512.pdf',
#  'https://arxiv.org/pdf/2203.16507.pdf',
#  'https://arxiv.org/pdf/2203.16506.pdf',
#  'https://arxiv.org/pdf/2203.16505.pdf',
#  'https://arxiv.org/pdf/2203.16502.pdf',
#  'https://arxiv.org/pdf/2203.16499.pdf',
#  'https://arxiv.org/pdf/2203.16497.pdf',
#  'https://arxiv.org/pdf/2203.16495.pdf',
#  'https://arxiv.org/pdf/2203.16494.pdf',
#  'https://arxiv.org/pdf/2203.16493.pdf',
#  'https://arxiv.org/pdf/2203.16492.pdf',
#  'https://arxiv.org/pdf/2203.16489.pdf',
#  'https://arxiv.org/pdf/2203.16487.pdf',
#  'https://arxiv.org/pdf/2203.16482.pdf',
#  'https://arxiv.org/pdf/2203.16481.pdf',
#  'https://arxiv.org/pdf/2203.16478.pdf',
#  'https://arxiv.org/pdf/2203.16476.pdf',
#  'https://arxiv.org/pdf/2203.16475.pdf',
#  'https://arxiv.org/pdf/2203.16474.pdf',
#  'https://arxiv.org/pdf/2203.16470.pdf',
#  'https://arxiv.org/pdf/2203.16465.pdf',
#  'https://arxiv.org/pdf/2203.16464.pdf',
#  'https://arxiv.org/pdf/2203.16463.pdf',
#  'https://arxiv.org/pdf/2203.16462.pdf',
#  'https://arxiv.org/pdf/2203.16460.pdf',
#  'https://arxiv.org/pdf/2203.16455.pdf',
#  'https://arxiv.org/pdf/2203.16454.pdf',
#  'https://arxiv.org/pdf/2203.16453.pdf',
#  'https://arxiv.org/pdf/2203.16452.pdf',
#  'https://arxiv.org/pdf/2203.16446.pdf',
#  'https://arxiv.org/pdf/2203.16434.pdf',
#  'https://arxiv.org/pdf/2203.16432.pdf',
#  'https://arxiv.org/pdf/2203.16428.pdf',
#  'https://arxiv.org/pdf/2203.16427.pdf',
#  'https://arxiv.org/pdf/2203.16423.pdf',
#  'https://arxiv.org/pdf/2203.16421.pdf',
#  'https://arxiv.org/pdf/2203.16419.pdf',
#  'https://arxiv.org/pdf/2203.16418.pdf',
#  'https://arxiv.org/pdf/2203.16417.pdf',
#  'https://arxiv.org/pdf/2203.16416.pdf',
#  'https://arxiv.org/pdf/2203.16414.pdf',
#  'https://arxiv.org/pdf/2203.16413.pdf',
#  'https://arxiv.org/pdf/2203.16408.pdf',
#  'https://arxiv.org/pdf/2203.16406.pdf',
#  'https://arxiv.org/pdf/2203.16401.pdf',
#  'https://arxiv.org/pdf/2203.16396.pdf',
#  'https://arxiv.org/pdf/2203.16394.pdf',
#  'https://arxiv.org/pdf/2203.16393.pdf',
#  'https://arxiv.org/pdf/2203.16392.pdf',
#  'https://arxiv.org/pdf/2203.16381.pdf',
#  'https://arxiv.org/pdf/2203.16373.pdf',
#  'https://arxiv.org/pdf/2203.16372.pdf',
#  'https://arxiv.org/pdf/2203.16370.pdf',
#  'https://arxiv.org/pdf/2203.16369.pdf',
#  'https://arxiv.org/pdf/2203.16365.pdf',
#  'https://arxiv.org/pdf/2203.16361.pdf',
#  'https://arxiv.org/pdf/2203.16354.pdf',
#  'https://arxiv.org/pdf/2203.16349.pdf',
#  'https://arxiv.org/pdf/2203.16346.pdf',
#  'https://arxiv.org/pdf/2203.16345.pdf',
#  'https://arxiv.org/pdf/2203.16344.pdf',
#  'https://arxiv.org/pdf/2203.16343.pdf',
#  'https://arxiv.org/pdf/2203.16341.pdf',
#  'https://arxiv.org/pdf/2203.16340.pdf',
#  'https://arxiv.org/pdf/2203.16338.pdf',
#  'https://arxiv.org/pdf/2203.16335.pdf',
#  'https://arxiv.org/pdf/2203.16331.pdf',
#  'https://arxiv.org/pdf/2203.16329.pdf',
#  'https://arxiv.org/pdf/2203.16328.pdf',
#  'https://arxiv.org/pdf/2203.16325.pdf',
#  'https://arxiv.org/pdf/2203.16319.pdf',
#  'https://arxiv.org/pdf/2203.16318.pdf',
#  'https://arxiv.org/pdf/2203.16317.pdf',
#  'https://arxiv.org/pdf/2203.16311.pdf',
#  'https://arxiv.org/pdf/2203.16309.pdf',
#  'https://arxiv.org/pdf/2203.16306.pdf',
#  'https://arxiv.org/pdf/2203.16301.pdf',
#  'https://arxiv.org/pdf/2203.16300.pdf',
#  'https://arxiv.org/pdf/2203.16297.pdf',
#  'https://arxiv.org/pdf/2203.16294.pdf',
#  'https://arxiv.org/pdf/2203.16291.pdf',
#  'https://arxiv.org/pdf/2203.16290.pdf',
#  'https://arxiv.org/pdf/2203.16289.pdf',
#  'https://arxiv.org/pdf/2203.16284.pdf',
#  'https://arxiv.org/pdf/2203.16282.pdf',
#  'https://arxiv.org/pdf/2203.16280.pdf',
#  'https://arxiv.org/pdf/2203.16279.pdf',
#  'https://arxiv.org/pdf/2203.16275.pdf',
#  'https://arxiv.org/pdf/2203.16274.pdf',
#  'https://arxiv.org/pdf/2203.16268.pdf',
#  'https://arxiv.org/pdf/2203.16267.pdf',
#  'https://arxiv.org/pdf/2203.16266.pdf',
#  'https://arxiv.org/pdf/2203.16265.pdf',
#  'https://arxiv.org/pdf/2203.16264.pdf',
#  'https://arxiv.org/pdf/2203.16263.pdf',
#  'https://arxiv.org/pdf/2203.16262.pdf',
#  'https://arxiv.org/pdf/2203.16258.pdf',
#  'https://arxiv.org/pdf/2203.16256.pdf',
#  'https://arxiv.org/pdf/2203.16255.pdf',
#  'https://arxiv.org/pdf/2203.16250.pdf',
#  'https://arxiv.org/pdf/2203.16248.pdf',
#  'https://arxiv.org/pdf/2203.16246.pdf',
#  'https://arxiv.org/pdf/2203.16244.pdf',
#  'https://arxiv.org/pdf/2203.16241.pdf',
#  'https://arxiv.org/pdf/2203.16230.pdf',
#  'https://arxiv.org/pdf/2203.16228.pdf',
#  'https://arxiv.org/pdf/2203.16225.pdf',
#  'https://arxiv.org/pdf/2203.16224.pdf',
#  'https://arxiv.org/pdf/2203.16223.pdf',
#  'https://arxiv.org/pdf/2203.16221.pdf',
#  'https://arxiv.org/pdf/2203.16220.pdf',
#  'https://arxiv.org/pdf/2203.16219.pdf',
#  'https://arxiv.org/pdf/2203.16218.pdf',
#  'https://arxiv.org/pdf/2203.16217.pdf',
#  'https://arxiv.org/pdf/2203.16214.pdf',
#  'https://arxiv.org/pdf/2203.16211.pdf',
#  'https://arxiv.org/pdf/2203.16210.pdf',
#  'https://arxiv.org/pdf/2203.16209.pdf',
#  'https://arxiv.org/pdf/2203.16202.pdf',
#  'https://arxiv.org/pdf/2203.16195.pdf',
#  'https://arxiv.org/pdf/2203.16194.pdf',
#  'https://arxiv.org/pdf/2203.16187.pdf',
#  'https://arxiv.org/pdf/2203.16181.pdf',
#  'https://arxiv.org/pdf/2203.16180.pdf',
#  'https://arxiv.org/pdf/2203.16177.pdf',
#  'https://arxiv.org/pdf/2203.16176.pdf',
#  'https://arxiv.org/pdf/2203.16175.pdf',
#  'https://arxiv.org/pdf/2203.16172.pdf',
#  'https://arxiv.org/pdf/2203.16171.pdf',
#  'https://arxiv.org/pdf/2203.16169.pdf',
#  'https://arxiv.org/pdf/2203.16168.pdf',
#  'https://arxiv.org/pdf/2203.16166.pdf',
#  'https://arxiv.org/pdf/2203.16163.pdf',
#  'https://arxiv.org/pdf/2203.16162.pdf',
#  'https://arxiv.org/pdf/2203.16161.pdf',
#  'https://arxiv.org/pdf/2203.16155.pdf',
#  'https://arxiv.org/pdf/2203.16154.pdf',
#  'https://arxiv.org/pdf/2203.16152.pdf',
#  'https://arxiv.org/pdf/2203.16151.pdf',
#  'https://arxiv.org/pdf/2203.16149.pdf',
#  'https://arxiv.org/pdf/2203.16148.pdf',
#  'https://arxiv.org/pdf/2203.16141.pdf',
#  'https://arxiv.org/pdf/2203.16136.pdf',
#  'https://arxiv.org/pdf/2203.16135.pdf',
#  'https://arxiv.org/pdf/2203.16130.pdf',
#  'https://arxiv.org/pdf/2203.16127.pdf',
#  'https://arxiv.org/pdf/2203.16126.pdf',
#  'https://arxiv.org/pdf/2203.16124.pdf',
#  'https://arxiv.org/pdf/2203.16123.pdf',
#  'https://arxiv.org/pdf/2203.16122.pdf',
#  'https://arxiv.org/pdf/2203.16117.pdf',
#  'https://arxiv.org/pdf/2203.16114.pdf',
#  'https://arxiv.org/pdf/2203.16110.pdf',
#  'https://arxiv.org/pdf/2203.16107.pdf',
#  'https://arxiv.org/pdf/2203.16106.pdf',
#  'https://arxiv.org/pdf/2203.16104.pdf',
#  'https://arxiv.org/pdf/2203.16102.pdf',
#  'https://arxiv.org/pdf/2203.16100.pdf',
#  'https://arxiv.org/pdf/2203.16097.pdf',
#  'https://arxiv.org/pdf/2203.16095.pdf',
#  'https://arxiv.org/pdf/2203.16094.pdf',
#  'https://arxiv.org/pdf/2203.16093.pdf',
#  'https://arxiv.org/pdf/2203.16092.pdf',
#  'https://arxiv.org/pdf/2203.16090.pdf',
#  'https://arxiv.org/pdf/2203.16089.pdf',
#  'https://arxiv.org/pdf/2203.16088.pdf',
#  'https://arxiv.org/pdf/2203.16085.pdf',
#  'https://arxiv.org/pdf/2203.16084.pdf',
#  'https://arxiv.org/pdf/2203.16075.pdf',
#  'https://arxiv.org/pdf/2203.16074.pdf',
#  'https://arxiv.org/pdf/2203.16073.pdf',
#  'https://arxiv.org/pdf/2203.16071.pdf',
#  'https://arxiv.org/pdf/2203.16069.pdf',
#  'https://arxiv.org/pdf/2203.16067.pdf',
#  'https://arxiv.org/pdf/2203.16063.pdf',
#  'https://arxiv.org/pdf/2203.16062.pdf',
#  'https://arxiv.org/pdf/2203.16060.pdf',
#  'https://arxiv.org/pdf/2203.16058.pdf',
#  'https://arxiv.org/pdf/2203.16057.pdf',
#  'https://arxiv.org/pdf/2203.16056.pdf',
#  'https://arxiv.org/pdf/2203.16054.pdf',
#  'https://arxiv.org/pdf/2203.16053.pdf',
#  'https://arxiv.org/pdf/2203.16051.pdf',
#  'https://arxiv.org/pdf/2203.16045.pdf',
#  'https://arxiv.org/pdf/2203.16044.pdf',
#  'https://arxiv.org/pdf/2203.16042.pdf',
#  'https://arxiv.org/pdf/2203.16041.pdf',
#  'https://arxiv.org/pdf/2203.16040.pdf',
#  'https://arxiv.org/pdf/2203.16038.pdf',
#  'https://arxiv.org/pdf/2203.16037.pdf',
#  'https://arxiv.org/pdf/2203.16035.pdf',
#  'https://arxiv.org/pdf/2203.16034.pdf',
#  'https://arxiv.org/pdf/2203.16033.pdf',
#  'https://arxiv.org/pdf/2203.16032.pdf',
#  'https://arxiv.org/pdf/2203.16031.pdf',
#  'https://arxiv.org/pdf/2203.16029.pdf',
#  'https://arxiv.org/pdf/2203.16028.pdf',
#  'https://arxiv.org/pdf/2203.16027.pdf',
#  'https://arxiv.org/pdf/2203.16024.pdf',
#  'https://arxiv.org/pdf/2203.16015.pdf',
#  'https://arxiv.org/pdf/2203.16014.pdf',
#  'https://arxiv.org/pdf/2203.16013.pdf',
#  'https://arxiv.org/pdf/2203.16009.pdf',
#  'https://arxiv.org/pdf/2203.16007.pdf',
#  'https://arxiv.org/pdf/2203.16006.pdf',
#  'https://arxiv.org/pdf/2203.16005.pdf',
#  'https://arxiv.org/pdf/2203.16004.pdf',
#  'https://arxiv.org/pdf/2203.16001.pdf',
#  'https://arxiv.org/pdf/2203.16000.pdf',
#  'https://arxiv.org/pdf/2203.15996.pdf',
#  'https://arxiv.org/pdf/2203.15994.pdf',
#  'https://arxiv.org/pdf/2203.15991.pdf',
#  'https://arxiv.org/pdf/2203.15990.pdf',
#  'https://arxiv.org/pdf/2203.15988.pdf',
#  'https://arxiv.org/pdf/2203.15987.pdf',
#  'https://arxiv.org/pdf/2203.15983.pdf',
#  'https://arxiv.org/pdf/2203.15982.pdf',
#  'https://arxiv.org/pdf/2203.15981.pdf',
#  'https://arxiv.org/pdf/2203.15980.pdf',
#  'https://arxiv.org/pdf/2203.15979.pdf',
#  'https://arxiv.org/pdf/2203.15977.pdf',
#  'https://arxiv.org/pdf/2203.15972.pdf',
#  'https://arxiv.org/pdf/2203.15970.pdf',
#  'https://arxiv.org/pdf/2203.15969.pdf',
#  'https://arxiv.org/pdf/2203.15968.pdf',
#  'https://arxiv.org/pdf/2203.15966.pdf',
#  'https://arxiv.org/pdf/2203.15965.pdf',
#  'https://arxiv.org/pdf/2203.15961.pdf',
#  'https://arxiv.org/pdf/2203.15959.pdf',
#  'https://arxiv.org/pdf/2203.15958.pdf',
#  'https://arxiv.org/pdf/2203.15955.pdf',
#  'https://arxiv.org/pdf/2203.15950.pdf',
#  'https://arxiv.org/pdf/2203.15948.pdf',
#  'https://arxiv.org/pdf/2203.15946.pdf',
#  'https://arxiv.org/pdf/2203.15943.pdf',
#  'https://arxiv.org/pdf/2203.15941.pdf',
#  'https://arxiv.org/pdf/2203.15936.pdf',
#  'https://arxiv.org/pdf/2203.15935.pdf',
#  'https://arxiv.org/pdf/2203.15932.pdf',
#  'https://arxiv.org/pdf/2203.15930.pdf',
#  'https://arxiv.org/pdf/2203.15928.pdf',
#  'https://arxiv.org/pdf/2203.15926.pdf',
#  'https://arxiv.org/pdf/2203.15925.pdf',
#  'https://arxiv.org/pdf/2203.15924.pdf',
#  'https://arxiv.org/pdf/2203.15921.pdf',
#  'https://arxiv.org/pdf/2203.15917.pdf',
#  'https://arxiv.org/pdf/2203.15913.pdf',
#  'https://arxiv.org/pdf/2203.15908.pdf',
#  'https://arxiv.org/pdf/2203.15901.pdf',
#  'https://arxiv.org/pdf/2203.15899.pdf',
#  'https://arxiv.org/pdf/2203.15898.pdf',
#  'https://arxiv.org/pdf/2203.15892.pdf',
#  'https://arxiv.org/pdf/2203.15884.pdf',
#  'https://arxiv.org/pdf/2203.15882.pdf',
#  'https://arxiv.org/pdf/2203.15880.pdf',
#  'https://arxiv.org/pdf/2203.15878.pdf',
#  'https://arxiv.org/pdf/2203.15876.pdf',
#  'https://arxiv.org/pdf/2203.15874.pdf',
#  'https://arxiv.org/pdf/2203.15873.pdf',
#  'https://arxiv.org/pdf/2203.15872.pdf',
#  'https://arxiv.org/pdf/2203.15867.pdf',
#  'https://arxiv.org/pdf/2203.15866.pdf',
#  'https://arxiv.org/pdf/2203.15865.pdf',
#  'https://arxiv.org/pdf/2203.15864.pdf',
#  'https://arxiv.org/pdf/2203.15862.pdf',
#  'https://arxiv.org/pdf/2203.15860.pdf',
#  'https://arxiv.org/pdf/2203.15859.pdf',
#  'https://arxiv.org/pdf/2203.15858.pdf',
#  'https://arxiv.org/pdf/2203.15857.pdf',
#  'https://arxiv.org/pdf/2203.15856.pdf',
#  'https://arxiv.org/pdf/2203.15854.pdf',
#  'https://arxiv.org/pdf/2203.15853.pdf',
#  'https://arxiv.org/pdf/2203.15851.pdf',
#  'https://arxiv.org/pdf/2203.15850.pdf',
#  'https://arxiv.org/pdf/2203.15848.pdf',
#  'https://arxiv.org/pdf/2203.15845.pdf',
#  'https://arxiv.org/pdf/2203.15841.pdf',
#  'https://arxiv.org/pdf/2203.15840.pdf',
#  'https://arxiv.org/pdf/2203.15837.pdf',
#  'https://arxiv.org/pdf/2203.15836.pdf',
#  'https://arxiv.org/pdf/2203.15835.pdf',
#  'https://arxiv.org/pdf/2203.15834.pdf',
#  'https://arxiv.org/pdf/2203.15833.pdf',
#  'https://arxiv.org/pdf/2203.15829.pdf',
#  'https://arxiv.org/pdf/2203.15827.pdf',
#  'https://arxiv.org/pdf/2203.15807.pdf',
#  'https://arxiv.org/pdf/2203.15806.pdf',
#  'https://arxiv.org/pdf/2203.15805.pdf',
#  'https://arxiv.org/pdf/2203.15804.pdf',
#  'https://arxiv.org/pdf/2203.15802.pdf',
#  'https://arxiv.org/pdf/2203.16520.pdf',
#  'https://arxiv.org/pdf/2203.16511.pdf',
#  'https://arxiv.org/pdf/2203.16490.pdf',
#  'https://arxiv.org/pdf/2203.16451.pdf',
#  'https://arxiv.org/pdf/2203.16442.pdf',
#  'https://arxiv.org/pdf/2203.16439.pdf',
#  'https://arxiv.org/pdf/2203.16437.pdf',
#  'https://arxiv.org/pdf/2203.16415.pdf',
#  'https://arxiv.org/pdf/2203.16409.pdf',
#  'https://arxiv.org/pdf/2203.16377.pdf',
#  'https://arxiv.org/pdf/2203.16357.pdf',
#  'https://arxiv.org/pdf/2203.16355.pdf',
#  'https://arxiv.org/pdf/2203.16339.pdf',
#  'https://arxiv.org/pdf/2203.16337.pdf',
#  'https://arxiv.org/pdf/2203.16336.pdf',
#  'https://arxiv.org/pdf/2203.16334.pdf',
#  'https://arxiv.org/pdf/2203.16298.pdf',
#  'https://arxiv.org/pdf/2203.16288.pdf',
#  'https://arxiv.org/pdf/2203.16273.pdf',
#  'https://arxiv.org/pdf/2203.16272.pdf',
#  'https://arxiv.org/pdf/2203.16261.pdf',
#  'https://arxiv.org/pdf/2203.16251.pdf',
#  'https://arxiv.org/pdf/2203.16237.pdf',
#  'https://arxiv.org/pdf/2203.16222.pdf',
#  'https://arxiv.org/pdf/2203.16205.pdf',
#  'https://arxiv.org/pdf/2203.16193.pdf',
#  'https://arxiv.org/pdf/2203.16165.pdf',
#  'https://arxiv.org/pdf/2203.16157.pdf',
#  'https://arxiv.org/pdf/2203.16087.pdf',
#  'https://arxiv.org/pdf/2203.16080.pdf',
#  'https://arxiv.org/pdf/2203.16036.pdf',
#  'https://arxiv.org/pdf/2203.15975.pdf',
#  'https://arxiv.org/pdf/2203.15974.pdf',
#  'https://arxiv.org/pdf/2203.15952.pdf',
#  'https://arxiv.org/pdf/2203.15945.pdf',
#  'https://arxiv.org/pdf/2203.15937.pdf',
#  'https://arxiv.org/pdf/2203.15927.pdf',
#  'https://arxiv.org/pdf/2203.15916.pdf',
#  'https://arxiv.org/pdf/2203.15879.pdf',
#  'https://arxiv.org/pdf/2203.15877.pdf',
#  'https://arxiv.org/pdf/2203.15863.pdf',
#  'https://arxiv.org/pdf/2203.03060.pdf',
#  'https://arxiv.org/pdf/2201.12277.pdf',
#  'https://arxiv.org/pdf/2203.15799.pdf',
#  'https://arxiv.org/pdf/2203.15798.pdf',
#  'https://arxiv.org/pdf/2203.15795.pdf',
#  'https://arxiv.org/pdf/2203.15794.pdf',
#  'https://arxiv.org/pdf/2203.15793.pdf',
#  'https://arxiv.org/pdf/2203.15792.pdf',
#  'https://arxiv.org/pdf/2203.15789.pdf',
#  'https://arxiv.org/pdf/2203.15788.pdf',
#  'https://arxiv.org/pdf/2203.15787.pdf',
#  'https://arxiv.org/pdf/2203.15786.pdf',
#  'https://arxiv.org/pdf/2203.15784.pdf',
#  'https://arxiv.org/pdf/2203.15783.pdf',
#  'https://arxiv.org/pdf/2203.15781.pdf',
#  'https://arxiv.org/pdf/2203.15780.pdf',
#  'https://arxiv.org/pdf/2203.15778.pdf',
#  'https://arxiv.org/pdf/2203.15776.pdf',
#  'https://arxiv.org/pdf/2203.15773.pdf',
#  'https://arxiv.org/pdf/2203.15772.pdf',
#  'https://arxiv.org/pdf/2203.15770.pdf',
#  'https://arxiv.org/pdf/2203.15767.pdf',
#  'https://arxiv.org/pdf/2203.15765.pdf',
#  'https://arxiv.org/pdf/2203.15760.pdf',
#  'https://arxiv.org/pdf/2203.15758.pdf',
#  'https://arxiv.org/pdf/2203.15755.pdf',
#  'https://arxiv.org/pdf/2203.15754.pdf',
#  'https://arxiv.org/pdf/2203.15753.pdf',
#  'https://arxiv.org/pdf/2203.15752.pdf',
#  'https://arxiv.org/pdf/2203.15748.pdf',
#  'https://arxiv.org/pdf/2203.15745.pdf',
#  'https://arxiv.org/pdf/2203.15738.pdf',
#  'https://arxiv.org/pdf/2203.15737.pdf',
#  'https://arxiv.org/pdf/2203.15733.pdf',
#  'https://arxiv.org/pdf/2203.15726.pdf',
#  'https://arxiv.org/pdf/2203.15724.pdf',
#  'https://arxiv.org/pdf/2203.15723.pdf',
#  'https://arxiv.org/pdf/2203.15722.pdf',
#  'https://arxiv.org/pdf/2203.15721.pdf',
#  'https://arxiv.org/pdf/2203.15720.pdf',
#  'https://arxiv.org/pdf/2203.15712.pdf',
#  'https://arxiv.org/pdf/2203.15709.pdf',
#  'https://arxiv.org/pdf/2203.15706.pdf',
#  'https://arxiv.org/pdf/2203.15705.pdf',
#  'https://arxiv.org/pdf/2203.15704.pdf',
#  'https://arxiv.org/pdf/2203.15703.pdf',
#  'https://arxiv.org/pdf/2203.15702.pdf',
#  'https://arxiv.org/pdf/2203.15700.pdf',
#  'https://arxiv.org/pdf/2203.15698.pdf',
#  'https://arxiv.org/pdf/2203.15696.pdf',
#  'https://arxiv.org/pdf/2203.15691.pdf',
#  'https://arxiv.org/pdf/2203.15687.pdf',
#  'https://arxiv.org/pdf/2203.15686.pdf',
#  'https://arxiv.org/pdf/2203.15685.pdf',
#  'https://arxiv.org/pdf/2203.15683.pdf',
#  'https://arxiv.org/pdf/2203.15674.pdf',
#  'https://arxiv.org/pdf/2203.15671.pdf',
#  'https://arxiv.org/pdf/2203.15667.pdf',
#  'https://arxiv.org/pdf/2203.15664.pdf',
#  'https://arxiv.org/pdf/2203.15662.pdf',
#  'https://arxiv.org/pdf/2203.15661.pdf',
#  'https://arxiv.org/pdf/2203.15657.pdf',
#  'https://arxiv.org/pdf/2203.15655.pdf',
#  'https://arxiv.org/pdf/2203.15653.pdf',
#  'https://arxiv.org/pdf/2203.15651.pdf',
#  'https://arxiv.org/pdf/2203.15643.pdf',
#  'https://arxiv.org/pdf/2203.15640.pdf',
#  'https://arxiv.org/pdf/2203.15638.pdf',
#  'https://arxiv.org/pdf/2203.15636.pdf',
#  'https://arxiv.org/pdf/2203.15633.pdf',
#  'https://arxiv.org/pdf/2203.15630.pdf',
#  'https://arxiv.org/pdf/2203.15629.pdf',
#  'https://arxiv.org/pdf/2203.15628.pdf',
#  'https://arxiv.org/pdf/2203.15627.pdf',
#  'https://arxiv.org/pdf/2203.15625.pdf',
#  'https://arxiv.org/pdf/2203.15619.pdf',
#  'https://arxiv.org/pdf/2203.15618.pdf',
#  'https://arxiv.org/pdf/2203.15614.pdf',
#  'https://arxiv.org/pdf/2203.15613.pdf',
#  'https://arxiv.org/pdf/2203.15612.pdf',
#  'https://arxiv.org/pdf/2203.15609.pdf',
#  'https://arxiv.org/pdf/2203.15607.pdf',
#  'https://arxiv.org/pdf/2203.15601.pdf',
#  'https://arxiv.org/pdf/2203.15597.pdf',
#  'https://arxiv.org/pdf/2203.15595.pdf',
#  'https://arxiv.org/pdf/2203.15592.pdf',
#  'https://arxiv.org/pdf/2203.15591.pdf',
#  'https://arxiv.org/pdf/2203.15590.pdf',
#  'https://arxiv.org/pdf/2203.15589.pdf',
#  'https://arxiv.org/pdf/2203.15588.pdf',
#  'https://arxiv.org/pdf/2203.15587.pdf',
#  'https://arxiv.org/pdf/2203.15586.pdf',
#  'https://arxiv.org/pdf/2203.15580.pdf',
#  'https://arxiv.org/pdf/2203.15578.pdf',
#  'https://arxiv.org/pdf/2203.15577.pdf',
#  'https://arxiv.org/pdf/2203.15576.pdf',
#  'https://arxiv.org/pdf/2203.15570.pdf',
#  'https://arxiv.org/pdf/2203.15568.pdf',
#  'https://arxiv.org/pdf/2203.15566.pdf',
#  'https://arxiv.org/pdf/2203.15565.pdf',
#  'https://arxiv.org/pdf/2203.15563.pdf',
#  'https://arxiv.org/pdf/2203.15561.pdf',
#  'https://arxiv.org/pdf/2203.15559.pdf',
#  'https://arxiv.org/pdf/2203.15558.pdf',
#  'https://arxiv.org/pdf/2203.15557.pdf',
#  'https://arxiv.org/pdf/2203.15556.pdf',
#  'https://arxiv.org/pdf/2203.15548.pdf',
#  'https://arxiv.org/pdf/2203.15547.pdf',
#  'https://arxiv.org/pdf/2203.15544.pdf',
#  'https://arxiv.org/pdf/2203.15542.pdf',
#  'https://arxiv.org/pdf/2203.15539.pdf',
#  'https://arxiv.org/pdf/2203.15536.pdf',
#  'https://arxiv.org/pdf/2203.15535.pdf',
#  'https://arxiv.org/pdf/2203.15534.pdf',
#  'https://arxiv.org/pdf/2203.15533.pdf',
#  'https://arxiv.org/pdf/2203.15529.pdf',
#  'https://arxiv.org/pdf/2203.15526.pdf',
#  'https://arxiv.org/pdf/2203.15522.pdf',
#  'https://arxiv.org/pdf/2203.15519.pdf',
#  'https://arxiv.org/pdf/2203.15516.pdf',
#  'https://arxiv.org/pdf/2203.15514.pdf',
#  'https://arxiv.org/pdf/2203.15511.pdf',
#  'https://arxiv.org/pdf/2203.15510.pdf',
#  'https://arxiv.org/pdf/2203.15509.pdf',
#  'https://arxiv.org/pdf/2203.15508.pdf',
#  'https://arxiv.org/pdf/2203.15507.pdf',
#  'https://arxiv.org/pdf/2203.15506.pdf',
#  'https://arxiv.org/pdf/2203.15504.pdf',
#  'https://arxiv.org/pdf/2203.15502.pdf',
#  'https://arxiv.org/pdf/2203.15501.pdf',
#  'https://arxiv.org/pdf/2203.15498.pdf',
#  'https://arxiv.org/pdf/2203.15496.pdf',
#  'https://arxiv.org/pdf/2203.15494.pdf',
#  'https://arxiv.org/pdf/2203.15491.pdf',
#  'https://arxiv.org/pdf/2203.15489.pdf',
#  'https://arxiv.org/pdf/2203.15488.pdf',
#  'https://arxiv.org/pdf/2203.15485.pdf',
#  'https://arxiv.org/pdf/2203.15483.pdf',
#  'https://arxiv.org/pdf/2203.15480.pdf',
#  'https://arxiv.org/pdf/2203.15479.pdf',
#  'https://arxiv.org/pdf/2203.15474.pdf',
#  'https://arxiv.org/pdf/2203.15469.pdf',
#  'https://arxiv.org/pdf/2203.15468.pdf',
#  'https://arxiv.org/pdf/2203.15467.pdf',
#  'https://arxiv.org/pdf/2203.15459.pdf',
#  'https://arxiv.org/pdf/2203.15458.pdf',
#  'https://arxiv.org/pdf/2203.15455.pdf',
#  'https://arxiv.org/pdf/2203.15448.pdf',
#  'https://arxiv.org/pdf/2203.15443.pdf',
#  'https://arxiv.org/pdf/2203.15442.pdf',
#  'https://arxiv.org/pdf/2203.15441.pdf',
#  'https://arxiv.org/pdf/2203.15439.pdf',
#  'https://arxiv.org/pdf/2203.15437.pdf',
#  'https://arxiv.org/pdf/2203.15435.pdf',
#  'https://arxiv.org/pdf/2203.15431.pdf',
#  'https://arxiv.org/pdf/2203.15429.pdf',
#  'https://arxiv.org/pdf/2203.15427.pdf',
#  'https://arxiv.org/pdf/2203.15426.pdf',
#  'https://arxiv.org/pdf/2203.15425.pdf',
#  'https://arxiv.org/pdf/2203.15424.pdf',
#  'https://arxiv.org/pdf/2203.15423.pdf',
#  'https://arxiv.org/pdf/2203.15419.pdf',
#  'https://arxiv.org/pdf/2203.15418.pdf',
#  'https://arxiv.org/pdf/2203.15414.pdf',
#  'https://arxiv.org/pdf/2203.15408.pdf',
#  'https://arxiv.org/pdf/2203.15407.pdf',
#  'https://arxiv.org/pdf/2203.15406.pdf',
#  'https://arxiv.org/pdf/2203.15404.pdf',
#  'https://arxiv.org/pdf/2203.15401.pdf',
#  'https://arxiv.org/pdf/2203.15400.pdf',
#  'https://arxiv.org/pdf/2203.15399.pdf',
#  'https://arxiv.org/pdf/2203.15398.pdf',
#  'https://arxiv.org/pdf/2203.15396.pdf',
#  'https://arxiv.org/pdf/2203.15395.pdf',
#  'https://arxiv.org/pdf/2203.15392.pdf',
#  'https://arxiv.org/pdf/2203.15390.pdf',
#  'https://arxiv.org/pdf/2203.15387.pdf',
#  'https://arxiv.org/pdf/2203.15386.pdf',
#  'https://arxiv.org/pdf/2203.15381.pdf',
#  'https://arxiv.org/pdf/2203.15380.pdf',
#  'https://arxiv.org/pdf/2203.15379.pdf',
#  'https://arxiv.org/pdf/2203.15377.pdf',
#  'https://arxiv.org/pdf/2203.15375.pdf',
#  'https://arxiv.org/pdf/2203.15371.pdf',
#  'https://arxiv.org/pdf/2203.15370.pdf',
#  'https://arxiv.org/pdf/2203.15369.pdf',
#  'https://arxiv.org/pdf/2203.15366.pdf',
#  'https://arxiv.org/pdf/2203.15364.pdf',
#  'https://arxiv.org/pdf/2203.15362.pdf',
#  'https://arxiv.org/pdf/2203.15361.pdf',
#  'https://arxiv.org/pdf/2203.15360.pdf',
#  'https://arxiv.org/pdf/2203.15359.pdf',
#  'https://arxiv.org/pdf/2203.15358.pdf',
#  'https://arxiv.org/pdf/2203.15355.pdf',
#  'https://arxiv.org/pdf/2203.15354.pdf',
#  'https://arxiv.org/pdf/2203.15353.pdf',
#  'https://arxiv.org/pdf/2203.15351.pdf',
#  'https://arxiv.org/pdf/2203.15350.pdf',
#  'https://arxiv.org/pdf/2203.15349.pdf',
#  'https://arxiv.org/pdf/2203.15346.pdf',
#  'https://arxiv.org/pdf/2203.15345.pdf',
#  'https://arxiv.org/pdf/2203.15340.pdf',
#  'https://arxiv.org/pdf/2203.15338.pdf',
#  'https://arxiv.org/pdf/2203.15337.pdf',
#  'https://arxiv.org/pdf/2203.15336.pdf',
#  'https://arxiv.org/pdf/2203.15335.pdf',
#  'https://arxiv.org/pdf/2203.15334.pdf',
#  'https://arxiv.org/pdf/2203.15333.pdf',
#  'https://arxiv.org/pdf/2203.15332.pdf',
#  'https://arxiv.org/pdf/2203.15331.pdf',
#  'https://arxiv.org/pdf/2203.15328.pdf',
#  'https://arxiv.org/pdf/2203.15326.pdf',
#  'https://arxiv.org/pdf/2203.15325.pdf',
#  'https://arxiv.org/pdf/2203.15324.pdf',
#  'https://arxiv.org/pdf/2203.15323.pdf',
#  'https://arxiv.org/pdf/2203.15322.pdf',
#  'https://arxiv.org/pdf/2203.15321.pdf',
#  'https://arxiv.org/pdf/2203.15320.pdf',
#  'https://arxiv.org/pdf/2203.15319.pdf',
#  'https://arxiv.org/pdf/2203.15318.pdf',
#  'https://arxiv.org/pdf/2203.15317.pdf',
#  'https://arxiv.org/pdf/2203.15316.pdf',
#  'https://arxiv.org/pdf/2203.15314.pdf',
#  'https://arxiv.org/pdf/2203.15312.pdf',
#  'https://arxiv.org/pdf/2203.15310.pdf',
#  'https://arxiv.org/pdf/2203.15309.pdf',
#  'https://arxiv.org/pdf/2203.15305.pdf',
#  'https://arxiv.org/pdf/2203.15302.pdf',
#  'https://arxiv.org/pdf/2203.15298.pdf',
#  'https://arxiv.org/pdf/2203.15297.pdf',
#  'https://arxiv.org/pdf/2203.15293.pdf',
#  'https://arxiv.org/pdf/2203.15290.pdf',
#  'https://arxiv.org/pdf/2203.15287.pdf',
#  'https://arxiv.org/pdf/2203.15285.pdf',
#  'https://arxiv.org/pdf/2203.15276.pdf',
#  'https://arxiv.org/pdf/2203.15274.pdf',
#  'https://arxiv.org/pdf/2203.15272.pdf',
#  'https://arxiv.org/pdf/2203.15270.pdf',
#  'https://arxiv.org/pdf/2203.15266.pdf',
#  'https://arxiv.org/pdf/2203.15260.pdf',
#  'https://arxiv.org/pdf/2203.15259.pdf',
#  'https://arxiv.org/pdf/2203.15258.pdf',
#  'https://arxiv.org/pdf/2203.15255.pdf',
#  'https://arxiv.org/pdf/2203.15254.pdf',
#  'https://arxiv.org/pdf/2203.15253.pdf',
#  'https://arxiv.org/pdf/2203.15252.pdf',
#  'https://arxiv.org/pdf/2203.15251.pdf',
#  'https://arxiv.org/pdf/2203.15249.pdf',
#  'https://arxiv.org/pdf/2203.15246.pdf',
#  'https://arxiv.org/pdf/2203.15245.pdf',
#  'https://arxiv.org/pdf/2203.15243.pdf',
#  'https://arxiv.org/pdf/2203.15241.pdf',
#  'https://arxiv.org/pdf/2203.15239.pdf',
#  'https://arxiv.org/pdf/2203.15235.pdf',
#  'https://arxiv.org/pdf/2203.15234.pdf',
#  'https://arxiv.org/pdf/2203.15233.pdf',
#  'https://arxiv.org/pdf/2203.15232.pdf',
#  'https://arxiv.org/pdf/2203.15230.pdf',
#  'https://arxiv.org/pdf/2203.15229.pdf',
#  'https://arxiv.org/pdf/2203.15228.pdf',
#  'https://arxiv.org/pdf/2203.15227.pdf',
#  'https://arxiv.org/pdf/2203.15224.pdf',
#  'https://arxiv.org/pdf/2203.15221.pdf',
#  'https://arxiv.org/pdf/2203.15219.pdf',
#  'https://arxiv.org/pdf/2203.15216.pdf',
#  'https://arxiv.org/pdf/2203.15215.pdf',
#  'https://arxiv.org/pdf/2203.15212.pdf',
#  'https://arxiv.org/pdf/2203.15210.pdf',
#  'https://arxiv.org/pdf/2203.15209.pdf',
#  'https://arxiv.org/pdf/2203.15207.pdf',
#  'https://arxiv.org/pdf/2203.15206.pdf',
#  'https://arxiv.org/pdf/2203.15205.pdf',
#  'https://arxiv.org/pdf/2203.15203.pdf',
#  'https://arxiv.org/pdf/2203.15202.pdf',
#  'https://arxiv.org/pdf/2203.15201.pdf',
#  'https://arxiv.org/pdf/2203.15200.pdf',
#  'https://arxiv.org/pdf/2203.15198.pdf',
#  'https://arxiv.org/pdf/2203.15195.pdf',
#  'https://arxiv.org/pdf/2203.15193.pdf',
#  'https://arxiv.org/pdf/2203.15191.pdf',
#  'https://arxiv.org/pdf/2203.15190.pdf',
#  'https://arxiv.org/pdf/2203.15189.pdf',
#  'https://arxiv.org/pdf/2203.15187.pdf',
#  'https://arxiv.org/pdf/2203.15186.pdf',
#  'https://arxiv.org/pdf/2203.15182.pdf',
#  'https://arxiv.org/pdf/2203.15178.pdf',
#  'https://arxiv.org/pdf/2203.15177.pdf',
#  'https://arxiv.org/pdf/2203.15176.pdf',
#  'https://arxiv.org/pdf/2203.15175.pdf',
#  'https://arxiv.org/pdf/2203.15174.pdf',
#  'https://arxiv.org/pdf/2203.15173.pdf',
#  'https://arxiv.org/pdf/2203.15172.pdf',
#  'https://arxiv.org/pdf/2203.15171.pdf',
#  'https://arxiv.org/pdf/2203.15166.pdf',
#  'https://arxiv.org/pdf/2203.15162.pdf',
#  'https://arxiv.org/pdf/2203.15158.pdf',
#  'https://arxiv.org/pdf/2203.15155.pdf',
#  'https://arxiv.org/pdf/2203.15152.pdf',
#  'https://arxiv.org/pdf/2203.15151.pdf',
#  'https://arxiv.org/pdf/2203.15150.pdf',
#  'https://arxiv.org/pdf/2203.15149.pdf',
#  'https://arxiv.org/pdf/2203.15145.pdf',
#  'https://arxiv.org/pdf/2203.15144.pdf',
#  'https://arxiv.org/pdf/2203.15143.pdf',
#  'https://arxiv.org/pdf/2203.15140.pdf',
#  'https://arxiv.org/pdf/2203.15135.pdf',
#  ...]

# %%
def fname_splitter(url):
    import pathlib
    split_up = pathlib.Path(url).parts
    # print(split_up)  # debug
    return(split_up[-1])
 
# fname_splitter('https://arxiv.org/pdf/2202.03914.pdf') # debug function

# %%
url= 'https://arxiv.org/pdf/2202.03914.pdf'
r = requests.get(url, allow_redirects=True)

# %%
pdflist=pdflist[:]

# %%
len(pdflist)
# Out:
# 1558

# %%
for url in pdflist: 
    fname=fname_splitter(url)
    path_fname="D:/arXiv/"+fname
    file_exists = exists(path_fname)
    if file_exists:
        print(f"megvan: {path_fname}")
    else:
        r = requests.get(url, allow_redirects=True)
        open(path_fname,"wb").write(r.content)
# Out:
# megvan: D:/arXiv/2109.03379.pdf
# megvan: D:/arXiv/2203.15937.pdf
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-f1b377bc1b83> in <module>
#       7     else:
#       8         r = requests.get(url, allow_redirects=True)
# ----> 9         open(path_fname,"wb").write(r.content)
#
# OSError: [Errno 28] No space left on device
