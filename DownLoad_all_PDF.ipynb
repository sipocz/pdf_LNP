# %% [markdown]
# <a href="https://colab.research.google.com/github/sipocz/pdf_NLP/blob/main/DownLoad_all_PDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from bs4 import  BeautifulSoup

# %%
url="https://github.com/sipocz/pdf_NLP/raw/296359e64839509b50760d6b29c47ede144c105a/doclist/ABB_doc_list.csv"
fname=url.split("/")[-1]

# %%
fname
# Out:
# 'ABB_doc_list.csv'

# %%
# !rm $fname
# !wget $url
# Out:
# rm: 'ABB_doc_list.csv' nem törölhető: Nincs ilyen fájl vagy könyvtár
# --2022-01-30 16:10:49--  https://github.com/sipocz/pdf_NLP/raw/296359e64839509b50760d6b29c47ede144c105a/doclist/ABB_doc_list.csv
# github.com (github.com) feloldása… 140.82.121.3
# Csatlakozás a következőhöz: github.com (github.com)[140.82.121.3]:443… kapcsolódva.
# HTTP kérés elküldve, várakozás válaszra… 302 Found
# Hely: https://raw.githubusercontent.com/sipocz/pdf_NLP/296359e64839509b50760d6b29c47ede144c105a/doclist/ABB_doc_list.csv [következik]
# --2022-01-30 16:10:49--  https://raw.githubusercontent.com/sipocz/pdf_NLP/296359e64839509b50760d6b29c47ede144c105a/doclist/ABB_doc_list.csv
# raw.githubusercontent.com (raw.githubusercontent.com) feloldása… 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Csatlakozás a következőhöz: raw.githubusercontent.com (raw.githubusercontent.com)[185.199.108.133]:443… kapcsolódva.
# HTTP kérés elküldve, várakozás válaszra… 200 OK
# Hossz: 221016 (216K) [text/plain]
# ...

# %%
df=pd.read_csv(fname)

# %%
df.columns=["url"]
df.head()
# Out:
#                                                  url
# 0  https://library.e.abb.com/public/d53ba16b5c364...
# 1  https://library.e.abb.com/public/bae93e60c2c94...
# 2  https://library.e.abb.com/public/18095336e48a4...
# 3  https://library.e.abb.com/public/53a79da968bf4...
# 4  https://library.e.abb.com/public/63d6abb3f1c74...

# %%
url_list=list(df.url)

# %%
list(url_list)
# Out:
# ['https://library.e.abb.com/public/d53ba16b5c3641be9eb0d99bbec918f7/7PAA000908_A_en_SECURITY%20-%20OPC%20Server%20for%20AC%20800M%20-%20Remote%20Code%20Execution%20Vulnerability.pdf',
#  'https://library.e.abb.com/public/bae93e60c2c941e790a86b9c8e76a491/3BDD011926_DF_en_Freelance%20Integrated%20HART%20Devices.pdf',
#  'https://library.e.abb.com/public/18095336e48a41bfb9715dcbb29d670b/3BDD011925_DH_en_Freelance%20Integrated%20PROFIBUS%20Devices.pdf',
#  'https://library.e.abb.com/public/53a79da968bf44ef96e9af9d875515a1/2VAA001302_CG_en_SPlus%20SD%20and%20MR%20Series%20Integrated%20PROFIBUS%20Devices.pdf',
#  'https://library.e.abb.com/public/63d6abb3f1c74e4a9c5395338c7bbfe2/2VAA001301_CH_en_SPlus%20SD%20and%20MR%20Series%20Integrated%20HART%20Devices.pdf',
#  'https://library.e.abb.com/public/0e3ada83bc604913a32b11700ea60fdf/2PAA103000_CH_en_Freelance%20Device%20Management%20Integrated%20FF%20Devices.pdf',
# ...

# %%
def query_pdf(url_in,dir):
    
    header={'User-Agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36"}

    
    
    url=url_in
    fname=url_in.split("/")[-1].replace("%20"," ")
    res=requests.get(url,headers=header)
    fname="/"+dir+"/"+fname
    #print(res.text)
    with open(fname,"wb") as file:
        file.write(res.content)

    return(res)

# %%
__operating_system__="LINUX"

# %%
if __operating_system__=="LINUX":
    base_path="home/sipocz/drive/ABB"

for i in range(len(url_list)):
    pdf1=query_pdf(url_list[i],base_path)

# %%
url_list[1]
# Out:
# 'https://library.e.abb.com/public/bae93e60c2c941e790a86b9c8e76a491/3BDD011926_DF_en_Freelance%20Integrated%20HART%20Devices.pdf'
